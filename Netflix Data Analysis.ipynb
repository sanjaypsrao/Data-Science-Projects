# %%
#Importing necessary library 
import pandas as pd 
import seaborn as sns

# %%
df=pd.read_csv("C:/Users/pssan/Desktop/Netflix Data.csv")

# %%
df
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
df.tail()
# Out:
#      Show_Id Category                                    Title     Director  \
# 7784   s7783    Movie                                     Zozo  Josef Fares
# 7785   s7784    Movie                                   Zubaan  Mozez Singh
# 7786   s7785    Movie                        Zulu Man in Japan          NaN
# 7787   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    Cast  \
# 7784  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                                            Nasty C
# 7787                         Adriano Zumbo, Rachel Khoo
# 7788                                                NaN
#
#                                                 Country        Release_Date  \
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# ...

# %%
df.shape
# Out:
# (7789, 11)

# %%
df.size
# Out:
# 85679

# %%
df.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %%
df.duplicated().sum()
# Out:
# 2

# %%
df[df.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (4809, 11)

# %%
for i in df.columns.values.tolist():
    print(i)
    print(df[i].unique())
    print("")
# Out:
# Show_Id
# ['s2' 's3' 's4' ... 's7782' 's7783' 's7784']
#
# Category
# ['Movie' 'TV Show']
#
# Title
# ['07:19' '23:59' '9' ... 'Zoom' 'Zozo' 'Zubaan']
#
# Director
# ['Jorge Michel Grau' 'Gilbert Chan' 'Shane Acker' ... 'Peter Hewitt'
#  'Josef Fares' 'Mozez Singh']
#
# Cast
# ['Demián Bichir, Héctor Bonilla, Oscar Serrano, Azalia Ortiz, Octavio Michel, Carmen Beato'
#  'Tedd Chan, Stella Chung, Henley Hii, Lawrence Koh, Tommy Kuan, Josh Lai, Mark Lee, Susan Leong, Benjamin Lim'
#  'Elijah Wood, John C. Reilly, Jennifer Connelly, Christopher Plummer, Crispin Glover, Martin Landau, Fred Tatasciore, Alan Oppenheimer, Tom Kane'
#  ...
#  'Tim Allen, Courteney Cox, Chevy Chase, Kate Mara, Ryan Newman, Michael Cassidy, Spencer Breslin, Rip Torn, Kevin Zegers'
#  'Imad Creidi, Antoinette Turk, Elias Gergi, Carmen Lebbos, Viktor Axelsson, Charbel Iskandar, Yasmine Awad'
# ...

# %% [markdown]
# # Most of the movies have which rating ???

# %%
df['Rating'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Most of the movies have duration of ???

# %%
sns.distplot(df['Minutes'])
# Out:
# C:\Users\pssan\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Minutes', ylabel='Density'>

# %% [markdown]
# # Find the maximum and minimum duration of the movies ???

# %%
df[['Minutes','Units']]=df['Duration'].str.split(' ',expand=True)

# %%
df.sample(3)
# Out:
#      Show_Id Category                      Title          Director  \
# 4733   s4734    Movie                    Pad Man          R. Balki
# 5928   s5928    Movie  Survivors Guide to Prison     Matthew Cooke
# 4576   s4577    Movie                 Off Course  Nacho G. Velilla
#
#                                                    Cast        Country  \
# 4733  Akshay Kumar, Sonam Kapoor, Radhika Apte, Jyot...          India
# 5928                                     Susan Sarandon  United States
# 4576  Yon González, Julián López, Blanca Suárez, Mal...          Spain
#
#            Release_Date Rating Duration  \
# 4733    August 21, 2018  PG-13  130 min
# 5928       May 24, 2018  TV-MA  103 min
# 4576  September 1, 2016  TV-MA  107 min
#
#                                                Type  \
# 4733  Dramas, International Movies, Romantic Movies
# 5928                                  Documentaries
# 4576                 Comedies, International Movies
#
# ...

# %%
df.Minutes = df.Minutes.astype(int)

# %%
df['Minutes'].max()
# Out:
# 253

# %%
df['Minutes'].min()
# Out:
# 1

# %% [markdown]
# # which Category is the most ?

# %%
df['Category'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Which country has highest number of tv shows ?

# %%
tvshows=df[df['Category']=='TV Show']

# %%
tvshows.Country.value_counts().head(5)
# Out:
# United States     27
# United Kingdom    19
# Japan             10
# South Korea       10
# Spain              7
# Name: Country, dtype: int64

# %% [markdown]
# # Find all the instances where: Category is 'Movie' and Type is 'Dramas' or Category is 'TV Show' & Type is 'Kids TV'.

# %%
df[(df['Category']=='TV Show') & (df['Type']=="Kids' TV")]
# Out:
#      Show_Id Category                                       Title  \
# 276     s277  TV Show                                Abby Hatcher
# 3582   s3583  TV Show            Lego Friends: Girls on a Mission
# 6204   s6204  TV Show  The Cat in the Hat Knows a Lot About That!
# 7668   s7667  TV Show                               World of Winx
#
#                         Director  \
# 276                  Kyran Kelly
# 3582  Andrew Tan, Stephen Murray
# 6204            Tony Collingwood
# 7668              Iginio Straffi
#
#                                                    Cast  \
# 276   Macy Drouin, Wyatt White, Paul Sun-Hyung Lee, ...
# 3582  Jasmine St. Clair, Allegra Clark, Rosamund Mar...
# 6204  Martin Short, Alexa Torrington, Jacob Ewaniuk,...
# 7668  Haven Paschall, Alysha Deslorieux, Jessica Paq...
#
#                                     Country      Release_Date Rating  \
# 276                   United States, Canada      July 1, 2020   TV-Y
# ...

# %%
df[(df['Category']=='Movie') & (df['Type']=='Dramas')]
# Out:
#      Show_Id Category                       Title           Director  \
# 4         s5    Movie                          21     Robert Luketic
# 7         s8    Movie                         187     Kevin Reynolds
# 170     s171    Movie                A Family Man      Mark Williams
# 232     s233    Movie  A Stoning in Fulham County      Larry Elikann
# 295     s296    Movie          Across Grace Alley      Ralph Macchio
# ...      ...      ...                         ...                ...
# 7417   s7416    Movie                      Victor  Brandon Dickerson
# 7422   s7421    Movie                     Villain   Philip Barantini
# 7449   s7448    Movie                         VS.           Ed Lilly
# 7465   s7464    Movie                   Wakefield      Robin Swicord
# 7480   s7479    Movie                   War Horse   Steven Spielberg
#
#                                                    Cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %% [markdown]
# #  In which year the highest number of the TV Shows & Movies were released ? Show with Bar Graph.

# %%
df['date_N']=pd.to_datetime(df['Release_Date'])

# %%
df.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore
#
#         Release_Date Rating Duration                                 Type  \
# 1  December 23, 2016  TV-MA   93 min         Dramas, International Movies
# 2  December 20, 2018      R   78 min  Horror Movies, International Movies
#
#                                          Description  Minutes Units     date_N
# 1  After a devastating earthquake hits Mexico Cit...       93   min 2016-12-23
# 2  When an army recruit is found dead, his fellow...       78   min 2018-12-20

# %%
df['date_N'].dt.year.value_counts()
# Out:
# 2019    1337
# 2020    1229
# 2018    1115
# 2017     752
# 2016     207
# 2021      78
# 2015      50
# 2014      14
# 2011      13
# 2013       7
# 2012       3
# 2009       2
# 2010       1
# 2008       1
# Name: date_N, dtype: int64

# %%
df['date_N'].dt.year.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Display all the Movies that were released in year 2020.

# %%
df['Year']=df['date_N'].dt.year

# %%
df[(df['Category']=='Movie') & (df['Year']==2020)]
# Out:
#      Show_Id Category                          Title  \
# 4         s5    Movie                             21
# 6         s7    Movie                            122
# 14       s15    Movie                           3022
# 27       s28    Movie                         #Alive
# 28       s29    Movie  #AnneFrank - Parallel Stories
# ...      ...      ...                            ...
# 7746   s7745    Movie    Yours Sincerely, Kanan Gill
# 7750   s7749    Movie                      الف مبروك
# 7762   s7761    Movie                      Zaki Chan
# 7783   s7782    Movie                           Zoom
# 7784   s7783    Movie                           Zozo
#
#                          Director  \
# 4                  Robert Luketic
# 6                 Yasir Al Yasiri
# 14                     John Suits
# 27                         Cho Il
# 28    Sabina Fedeli, Anna Migotto
# ...                           ...
# 7746                 Neville Shah
# 7750            Ahmed Nader Galal
# ...

# %% [markdown]
# # Show only the Titles of all TV Shows that were released in India only.

# %%
df[(df['Category']=='TV Show') & (df['Country']=='India')]['Title']
# Out:
# 132                                 7 (Seven)
# 2406                                    GHOUL
# 3119             Jamtara - Sabka Number Ayega
# 4724                          Paava Kadhaigal
# 6037    Th Eena Meena Deeka Chase Comedy Show
# Name: Title, dtype: object

# %% [markdown]
# # Show Top 10 Directors, who gave the highest number of TV Shows & Movies to Netflix ?

# %%
df['Director'].value_counts()
# Out:
# Raúl Campos, Jan Suter             18
# Marcus Raboy                       15
# Jay Karas                          14
# Cathy Garcia-Molina                13
# Jay Chapman                        12
#                                    ..
# Robert Osman, Nathanael Wiseman     1
# Ilya Naishuller                     1
# Paresh Mokashi                      1
# Jon Hurwitz, Hayden Schlossberg     1
# Mozez Singh                         1
# Name: Director, Length: 3614, dtype: int64
